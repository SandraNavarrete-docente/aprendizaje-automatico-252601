# %% [markdown]
# <a href="https://colab.research.google.com/github/SandraNavarrete-docente/aprendizaje-automatico-252601/blob/main/ExplorarTitanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
BASE_FOLDER = "/content/drive/MyDrive/Colab Notebooks/AA2526/"
sys.path.append(BASE_FOLDER)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path = BASE_FOLDER + 'data/titanic.csv'
df = pd.DataFrame(pd.read_csv(path))
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_num = df.select_dtypes(include=['number'])
df_num.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
df_cat = df.select_dtypes(include=['object'])
df_cat.head()
# Out:
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %% [markdown]
# ## Estadistica Descriptiva

# %%
print('Dataset: TITANIC')
print(f'Numero de instancias: {df.shape[0]}')
print(f'Numero de atributos: {df.shape[1]}')
print(f'Numero de atributos numericos: {df_num.shape[1]}')
print(f'Numero de atributos categoricos: {df_cat.shape[1]}')
print(f'Nombres de atributos numericos: {df_num.columns}')
print(f'Nombres de atributos categoricos: {df_cat.columns}')
print(f'Tipos de datos de los atributos numericos: {df_num.dtypes}')
print(f'Tipos de datos de los atributos categoricos: {df_cat.dtypes}')
# Out:
# Dataset: TITANIC
# Numero de instancias: 891
# Numero de atributos: 12
# Numero de atributos numericos: 7
# Numero de atributos categoricos: 5
# Nombres de atributos numericos: Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')
# Nombres de atributos categoricos: Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')
# Tipos de datos de los atributos numericos: PassengerId      int64
# Survived         int64
# Pclass           int64
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# dtype: object
# Tipos de datos de los atributos categoricos: Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %% [markdown]
# ### Estadistica de Atributos

# %%
import numpy as np

SibSp, frecuencia = np.unique(df['SibSp'], return_counts = True )
print(f'Atributo: SibSp')
print(f'Valores: {SibSp}')
print(f'Frecuencia: {frecuencia}')
# Out:
# Atributo: SibSp
# Valores: [0 1 2 3 4 5 8]
# Frecuencia: [608 209  28  16  18   5   7]

# %%
plt.figure(figsize= (8,6))
plt.hist(df['Age'], bins =20 , color='blue', edgecolor='black')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Histograma de Edades')
plt.show()

# %%
parch, frecuencia = np.unique(df['Parch'], return_counts = True )
print(f'Atributo: Parch')
print(f'Valores: {parch}')
print(f'Frecuencia: {frecuencia}')
# Out:
# Atributo: Parch
# Valores: [0 1 2 3 4 5 6]
# Frecuencia: [678 118  80   5   4   5   1]

# %%
plt.figure(figsize= (8,6))
plt.pie(frecuencia, labels = parch, autopct = '%1.1f%%')
plt.title('Cantidad Padres y Hermanos')
plt.show()

# %%
Sex, frecuencia = np.unique(df['Sex'], return_counts = True )
print(f'Atributo: Sex')
print(f'Valores: {Sex}')
print(f'Frecuencia: {frecuencia}')
# Out:
# Atributo: Sex
# Valores: ['female' 'male']
# Frecuencia: [314 577]

# %%
plt.figure(figsize= (8,6))
plt.pie(frecuencia, labels = Sex, autopct = '%1.1f%%')
plt.title('Sex')
plt.show()

# %%
Pclass, frecuencia = np.unique(df['Pclass'], return_counts = True )
print(f'Atributo: Pclass')
print(f'Valores: {Pclass}')
print(f'Frecuencia: {frecuencia}')
# Out:
# Atributo: Pclass
# Valores: [1 2 3]
# Frecuencia: [216 184 491]

# %%
plt.figure(figsize= (8,6))
plt.pie(frecuencia, labels = Pclass, autopct = '%1.1f%%')
plt.title('Clase')
plt.show()

# %%
Survived, frecuencia = np.unique(df['Survived'], return_counts = True )
print(f'Atributo: Survived')
print(f'Valores: {Survived}')
print(f'Frecuencia: {frecuencia}')
# Out:
# Atributo: Survived
# Valores: [0 1]
# Frecuencia: [549 342]

# %%
frecuenciaAbs = df['Survived'].value_counts( normalize = True)
print(f'Atributo: Survived')
print(f'Frecuencia Absoluta: {frecuenciaAbs}')
# Out:
# Atributo: Survived
# Frecuencia Absoluta: Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize= (8,6))
plt.pie(frecuencia, labels = Survived, autopct = '%1.1f%%')
plt.title('Survived')
plt.show()

# %%
import seaborn as sns
sns.kdeplot(x='Fare', data=df, fill=True)
plt.title('Grafico de Densidad de la Tarifa')
plt.show()
