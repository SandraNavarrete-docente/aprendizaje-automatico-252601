# %% [markdown]
# # 🎓 **Taller 4.5.2: Taller de Métodos de Clustering Jerarquico**

# %% [markdown]
# ## OBJETIVOS DEL TALLER:
# En esta práctica vamos a ver cómo funcionan los algoritmos jerárquicos vistos en clase: el aglomerativo y el divisivo.

# %% [markdown]
# # 🔧 **CONFIGURACIÓN INICIAL**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import itertools as it
from matplotlib.cm import get_cmap
from scipy.cluster.hierarchy import dendrogram

plt.rcParams['figure.figsize'] = [8, 8]

# %% [markdown]
# # 📁 **CARGAR LOS DATASETS Y GRAFICAR SUS DISTRIBUCIONES**

# %%
# Cargar dataset artificial
def cargar_dataset(nombre_dataset):
    try:
        # Intentar cargar desde URL alternativa
        data_file_url = "https://raw.githubusercontent.com/SandraNavarrete-docente/aprendizaje-automatico-252601/main/04-MODELOS-NO-SUPERVISADOS/data/"+nombre_dataset
        D = np.array(pd.read_excel(data_file_url,header=0))
        print("✅ Dataset cargado desde URL GitHub")
        return D
    except:
        print("❌ No se pudo cargar el dataset")
        return None

def cargar_dataset_csv(nombre_dataset):
    try:
        # Intentar cargar desde URL alternativa
        data_file_url = "https://raw.githubusercontent.com/SandraNavarrete-docente/aprendizaje-automatico-252601/main/04-MODELOS-NO-SUPERVISADOS/data/"+nombre_dataset
        D = np.array(pd.read_csv(data_file_url,header=0))
        print("✅ Dataset cargado desde URL GitHub")
        return D
    except:
        print("❌ No se pudo cargar el dataset")
        return None

# %%
# Cargar dataset
D =cargar_dataset("dataset_reducido.xlsx")
Dx = D[:,0:2]
Dx = Dx[ np.random.choice(np.arange(Dx.shape[0]), Dx.shape[0], replace=False) ,:]
Dy = D[:,2]
fig, ax = plt.subplots(figsize=(6,3))
ax.scatter(Dx[:,0],Dx[:,1], c=Dy)
# Out:
# ✅ Dataset cargado desde URL GitHub

# %% [markdown]
# # Incluimos una serie de funciones que nos van a permitir visualizar los resultados.

# %%
def plot_particiones_grid(Dx, mParticiones, figsize=(15, 10)):

    n_partitions = mParticiones.shape[1] -1
    # Calcular distribución de subplots
    cols = min(4, n_partitions)  # Máximo 4 columnas
    rows = (n_partitions + cols - 1) // cols  # Redondeo hacia arriba

    fig, axes = plt.subplots(rows, cols, figsize=figsize, squeeze=False)
    fig.suptitle('Particiones Jerárquicas Aglomerativas', fontsize=16, fontweight='bold')

    # Obtener colormap una sola vez
    cmap = plt.colormaps['tab20']
    n_samples = Dx.shape[0]
    vals = np.linspace(0, 1, n_samples + 2)[1:-1]
    rgba = cmap(vals)

    for k in range(n_partitions):
        row = k // cols
        col = k % cols
        ax = axes[row, col]

        # Obtener etiquetas de cluster para esta partición
        labels = mParticiones[:, k]

        # Crear scatter plot
        scatter = ax.scatter(Dx[:, 0], Dx[:, 1],
                            c=rgba[labels],
                            s=50, alpha=0.8, edgecolors='w', linewidth=0.5)

        ax.set_title(f'K = {k+1} clusters', fontsize=11)
        ax.set_xlabel('X1')
        ax.set_ylabel('X2')
        ax.grid(True, alpha=0.3, linestyle='--')

    # Ocultar ejes vacíos si hay menos subplots que celdas
    for k in range(n_partitions, rows * cols):
        row = k // cols
        col = k % cols
        axes[row, col].axis('off')

    plt.tight_layout()
    plt.subplots_adjust(top=0.93)  # Ajustar para el título
    return fig, axes

# %%
# Muestra los ejemplos coloreados según su pertenencia a los clústeres
# K indica el número de clústeres a mostrar a partir de la jerarquía
def plot_particion_K(Dx, mParticiones,K):
  # Nueva sintaxis para obtener colormaps
    cmap = plt.colormaps['tab20']
    n_samples = Dx.shape[0]
    vals = np.linspace(0, 1, n_samples + 2)[1:-1]  # Más eficiente
    rgba = cmap(vals)
    # Crear gráfico
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.scatter(Dx[:, 0], Dx[:, 1],
               c=rgba[mParticiones[:, K-1]],  # Nota: no necesita el último ":"
               s=60, alpha=0.8)
    return fig, ax

# Muestra el dendrograma de la jerarquía
def plot_dendrograma_de_mparticiones(mD, mParticiones):
    nPasos = mD.shape[0]-1
    distancias = np.zeros(nPasos)
    tamanyos = np.zeros(nPasos)
    uniones = np.zeros(2*nPasos,dtype=np.int8)
    uniones.shape=(nPasos,2)

    mNParticiones = mParticiones.copy()
    for n in np.arange(mNParticiones.shape[0]):
        valor = mParticiones[n,mNParticiones.shape[1]-1]
        mNParticiones[mParticiones==valor] = n

    k = 0
    aux = np.array(range(mNParticiones.shape[1]-1))
    for n in aux[::-1]:
        # cual es el diferente?
        prim_diferencia = np.where(mParticiones[:,n]!=mParticiones[:,n+1])[0][0]
        submatriz = mNParticiones[:,:n+1]
        submatriz[submatriz==mNParticiones[prim_diferencia,n]] = mNParticiones.shape[1]+k
        mNParticiones[:,:n+1] = submatriz
        uniones[k,:] = np.unique(mNParticiones[mNParticiones[:,n]==mNParticiones.shape[1]+k,n+1])
        tamanyos[k] = np.sum(mNParticiones[:,n]==mNParticiones.shape[1]+k)

        vs = mNParticiones[:,n+1]
        distancias[k] = 1 / (2 * tamanyos[k]) * (
            np.sum(mD[ np.ix_(np.where(vs == uniones[k,0])[0],
                              np.where(vs == uniones[k,1])[0])])+
            np.sum(mD[ np.ix_(np.where(vs == uniones[k,1])[0],
                              np.where(vs == uniones[k,0])[0])]))
        k += 1

    distancias = np.arange(uniones.shape[0])
    # Creamos la matriz de enlaces que necesita el método dendrogram de scipy
    mEnlaces = np.column_stack([uniones, distancias, tamanyos]).astype(float)

    plt.figure(figsize=(15, 8))
    plt.title('Dendrograma de Clustering Jerárquico')
    plt.xlabel('Índice del caso')
    plt.ylabel('Distancia')
    dendrogram(mEnlaces)
    plt.show()

# %% [markdown]
# # 🎯 **1:Cree el Algoritmo de Clustering Divisivo (TOP-DOWN)**

# %% [markdown]
# ##Calcular la matriz de distancias del dataset.

# %%
def distancia_euclidiana(x, y):
    return np.sqrt(np.sum((x-y)**2))

def matriz_distancias(X, distancia):
    mD = np.zeros((X.shape[0],X.shape[0]))
    for pair in it.product(np.arange(X.shape[0]), repeat=2):
        mD[pair] = distancia(X[pair[0],:],X[pair[1],:])
    return mD

# %%
mD = matriz_distancias(Dx, distancia_euclidiana) # P1 Complete su codigo aqui
plt.figure(figsize=(5, 4))
plt.imshow(mD, cmap='viridis', vmin=mD.min(), vmax=mD.max(), aspect='auto')
plt.colorbar(label='Distancia')
plt.title('Matriz de Distancias', fontweight='bold')
plt.xlabel('Puntos')
plt.ylabel('Puntos')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Crear el algoritmo Divisivo

# %%
def clustering_divisivo(mD, disimilitud_intracluster, separador, imprimir, **kwargs):
    # En esta matriz almacenaremos las sucesivas particiones (clusterings) de los
    # datos. Sucesivas, porque cada paso del bucle de abajo realizará una separación
    # entre los dos clusters más diferentes, hasta que haya un cluster por elemento
    # del dataset.
    mParticiones = np.zeros((mD.shape[0], mD.shape[0]), dtype = np.int64)
    # Recorremos `mParticiones` (en esta ocasión, de manera creciente) guardando
    # los agrupamientos
    for n in range(1, mParticiones.shape[1]):
        if imprimir:
          print(f'Paso número {n}')
        # Al empezar, asignamos el agrupamiento anterior al actual, ya que el
        # agrupamiento en el momento anterior (`n-1`) únicamente sufrirá alguna
        # modificación para dividir los dos clusters más separados.
        mParticiones[:,n] = mParticiones[:,n-1]
        # Calculamos la disimilitud intracluster
        rDisIntraCluster = disimilitud_intracluster(mD, mParticiones[:,n-1], n)
        if imprimir:
          print(f'Disimilitud intracluster: {rDisIntraCluster}')
        # Y escogemos el cluster en el que mayor sea la disimilitud
        iClusterADiv = np.argmax(rDisIntraCluster)
        if imprimir:
          print(f'Cluster a dividir: {iClusterADiv}')
        # Separamos dicho cluster en 2 sub-clusters siguiendo el criterio escogido
        iAClusterNuevo = separador(mD, mParticiones[:,n-1], iClusterADiv, **kwargs)
        if imprimir:
          print(f'Número de elementos a asignar al nuevo cluster {n}: {len(iAClusterNuevo)}')
        mParticiones[iAClusterNuevo, n] = n
    return mParticiones

# %% [markdown]
# ### Funciones para calcular la disimilitud intraclúster

# %%
def disimilitud_diametro(mD, particion, n):
    res = [ np.max((mD[ np.ix_(particion == pn , particion == pn) ] +
                    np.transpose(mD[ np.ix_(particion == pn , particion == pn) ]))/ 2)
           for pn in np.arange(n)]
    return res

# %%
def disimilitud_media(mD, particion, n):
    res = [np.sum(mD[ np.ix_(particion == pn , particion == pn) ])
                              / (np.sum(particion == pn)**2)
                              for pn in np.arange(n)]
    return res

# %% [markdown]
# ### Criterios para separar un cluster

# %%
def separacion_macnaughton_smith(mDglobal, particion, iCluster):
    indsClust = np.where(particion==iCluster)[0]
    mD = mDglobal[ np.ix_(indsClust , indsClust)]

    SA = np.array([np.argmax(1/((mD.shape[0]-1)*2)*(np.sum(mD,axis=0)+np.sum(mD,axis=1)))])
    SB = np.delete(np.arange(mD.shape[0]), SA)
    if (SB.size == 1):
        return indsClust[SA]
    while True:
        res = np.zeros(SB.size)
        # Para todos los elementos del cluster original SB
        for i in np.arange(SB.size):
            SBa = np.delete(SB,i)
            res[i] = (# distancia media con los otros elementos de SB
                np.sum(mD[ SB[i] , SBa ]) +
                np.sum(mD[ SBa , SB[i] ])
            ) / (2 * SBa.size) - (# distancia media con los elementos ya movidos a SA
                np.sum(mD[ SB[i] , SA ]) +
                np.sum(mD[ SA , SB[i] ])
            ) / (2 * SA.size)
        # Si en todos los casos (todas las posiciones del vector res) la distancia
        # es negativa quiere decir que no existe ningún elemento en SB más cercano
        # a SA que al resto de SB
        if np.all(res < 0):
            break
        iToChange = np.argmax(res)
        SA = np.sort(np.append(SA, SB[iToChange]))
        SB = np.delete(np.arange(mD.shape[0]), SA)
    # Devolveremos los índices de los elementos que pertenecerán al clúster SA
    return indsClust[SA]

# %%
from sklearn.cluster import KMeans

def separacion_Kmeans(mDglobal, particion, iCluster, Dxglobal):
    indsClust = np.where(particion==iCluster)[0]
    Dx = Dxglobal[indsClust,:]
    modelo = KMeans(n_clusters=2)
    modelo = modelo.fit(Dx)
    Dyp = modelo.predict(Dx)
    # Devolveremos los índices de los ejemplos asignados
    # al segundo clúster
    return indsClust[Dyp==1]

# %% [markdown]
# ## Ahora ya estamos en disposición de realizar el clustering jerárquico divisivo.
# *   Usar el criterio de disimilitud media y diámetro en combinación con la separación de Macnaughton-Smith y la de K-means
# *   Mostrar (plotear) las respectivas particiones con 5 clústeres.

# %%
# Usando disimilitud media y el método de separacion de Macnaughton-Smith
mParticiones = clustering_divisivo(mD, disimilitud_media, separacion_macnaughton_smith, True)
# Out:
# Paso número 1
# Disimilitud intracluster: [np.float64(7.320333481796019)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 1: 11
# Paso número 2
# Disimilitud intracluster: [np.float64(3.6388874885940994), np.float64(3.6401805352754173)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 2: 5
# Paso número 3
# Disimilitud intracluster: [np.float64(3.6388874885940994), np.float64(1.9469226515718252), np.float64(1.6004322959219144)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 3: 5
# Paso número 4
# Disimilitud intracluster: [np.float64(1.9447777636023769), np.float64(1.9469226515718252), np.float64(1.6004322959219144), np.float64(1.6003148325792946)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 4: 3
# Paso número 5
# Disimilitud intracluster: [np.float64(1.9447777636023769), np.float64(0.8908870639116443), np.float64(1.6004322959219144), np.float64(1.6003148325792946), np.float64(0.8926802317747595)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 5: 3
# Paso número 6
# Disimilitud intracluster: [np.float64(0.8890110365918285), np.float64(0.8908870639116443), np.float64(1.6004322959219144), np.float64(1.6003148325792946), np.float64(0.8926802317747595), np.float64(0.8894970042574598)]
# Cluster a dividir: 2
# Número de elementos a asignar al nuevo cluster 6: 2
# Paso número 7
# Disimilitud intracluster: [np.float64(0.8890110365918285), np.float64(0.8908870639116443), np.float64(0.8891396041288877), np.float64(1.6003148325792946), np.float64(0.8926802317747595), np.float64(0.8894970042574598), np.float64(0.5009998778674726)]
# Cluster a dividir: 3
# Número de elementos a asignar al nuevo cluster 7: 3
# Paso número 8
# Disimilitud intracluster: [np.float64(0.8890110365918285), np.float64(0.8908870639116443), np.float64(0.8891396041288877), np.float64(0.5000135654099022), np.float64(0.8926802317747595), np.float64(0.8894970042574598), np.float64(0.5009998778674726), np.float64(0.8892952818174589)]
# Cluster a dividir: 4
# Número de elementos a asignar al nuevo cluster 8: 1
# Paso número 9
# Disimilitud intracluster: [np.float64(0.8890110365918285), np.float64(0.8908870639116443), np.float64(0.8891396041288877), np.float64(0.5000135654099022), np.float64(0.5011660242763869), np.float64(0.8894970042574598), np.float64(0.5009998778674726), np.float64(0.8892952818174589), np.float64(0.0)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 9: 1
# Paso número 10
# Disimilitud intracluster: [np.float64(0.8890110365918285), np.float64(0.5019391318905735), np.float64(0.8891396041288877), np.float64(0.5000135654099022), np.float64(0.5011660242763869), np.float64(0.8894970042574598), np.float64(0.5009998778674726), np.float64(0.8892952818174589), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 5
# Número de elementos a asignar al nuevo cluster 10: 1
# Paso número 11
# Disimilitud intracluster: [np.float64(0.8890110365918285), np.float64(0.5019391318905735), np.float64(0.8891396041288877), np.float64(0.5000135654099022), np.float64(0.5011660242763869), np.float64(0.500369156812248), np.float64(0.5009998778674726), np.float64(0.8892952818174589), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 7
# Número de elementos a asignar al nuevo cluster 11: 1
# Paso número 12
# Disimilitud intracluster: [np.float64(0.8890110365918285), np.float64(0.5019391318905735), np.float64(0.8891396041288877), np.float64(0.5000135654099022), np.float64(0.5011660242763869), np.float64(0.500369156812248), np.float64(0.5009998778674726), np.float64(0.5004137173460201), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 2
# Número de elementos a asignar al nuevo cluster 12: 1
# Paso número 13
# Disimilitud intracluster: [np.float64(0.8890110365918285), np.float64(0.5019391318905735), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.5011660242763869), np.float64(0.500369156812248), np.float64(0.5009998778674726), np.float64(0.5004137173460201), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 13: 1
# Paso número 14
# Disimilitud intracluster: [np.float64(0.5000016332813324), np.float64(0.5019391318905735), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.5011660242763869), np.float64(0.500369156812248), np.float64(0.5009998778674726), np.float64(0.5004137173460201), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 14: 1
# Paso número 15
# Disimilitud intracluster: [np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.5011660242763869), np.float64(0.500369156812248), np.float64(0.5009998778674726), np.float64(0.5004137173460201), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 4
# Número de elementos a asignar al nuevo cluster 15: 1
# Paso número 16
# Disimilitud intracluster: [np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.0), np.float64(0.500369156812248), np.float64(0.5009998778674726), np.float64(0.5004137173460201), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 6
# Número de elementos a asignar al nuevo cluster 16: 1
# Paso número 17
# Disimilitud intracluster: [np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.0), np.float64(0.500369156812248), np.float64(0.0), np.float64(0.5004137173460201), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 7
# Número de elementos a asignar al nuevo cluster 17: 1
# Paso número 18
# Disimilitud intracluster: [np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.0), np.float64(0.500369156812248), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 5
# Número de elementos a asignar al nuevo cluster 18: 1
# Paso número 19
# Disimilitud intracluster: [np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 2
# Número de elementos a asignar al nuevo cluster 19: 1
# Paso número 20
# Disimilitud intracluster: [np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.0), np.float64(0.5000135654099022), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 3
# Número de elementos a asignar al nuevo cluster 20: 1
# Paso número 21
# Disimilitud intracluster: [np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 21: 1

# %%
plot_dendrograma_de_mparticiones(mD, mParticiones)

# %%
K = 5 # parametro para mostrar una particion
plot_particion_K(Dx, mParticiones, K)
# Out:
# (<Figure size 1000x500 with 1 Axes>, <Axes: >)

# %%
# Usando disimilitud diámetro y el método de separacion de Macnaughton-Smith
mParticiones = clustering_divisivo(mD, disimilitud_diametro, separacion_macnaughton_smith, True)
# Out:
# Paso número 1
# Disimilitud intracluster: [np.float64(21.0000098308137)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 1: 11
# Paso número 2
# Disimilitud intracluster: [np.float64(10.001327366161615), np.float64(10.00097531413936)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 2: 5
# Paso número 3
# Disimilitud intracluster: [np.float64(5.000000871371285), np.float64(10.00097531413936), np.float64(4.000267986998996)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 3: 5
# Paso número 4
# Disimilitud intracluster: [np.float64(5.000000871371285), np.float64(5.001849350471439), np.float64(4.000267986998996), np.float64(4.00006378405076)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 4: 3
# Paso número 5
# Disimilitud intracluster: [np.float64(5.000000871371285), np.float64(2.0000403252685306), np.float64(4.000267986998996), np.float64(4.00006378405076), np.float64(2.0082754203527884)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 5: 3
# Paso número 6
# Disimilitud intracluster: [np.float64(2.0002054831026763), np.float64(2.0000403252685306), np.float64(4.000267986998996), np.float64(4.00006378405076), np.float64(2.0082754203527884), np.float64(2.000129202242305)]
# Cluster a dividir: 2
# Número de elementos a asignar al nuevo cluster 6: 3
# Paso número 7
# Disimilitud intracluster: [np.float64(2.0002054831026763), np.float64(2.0000403252685306), np.float64(1.0000271308198043), np.float64(4.00006378405076), np.float64(2.0082754203527884), np.float64(2.000129202242305), np.float64(2.0000039700523096)]
# Cluster a dividir: 3
# Número de elementos a asignar al nuevo cluster 7: 2
# Paso número 8
# Disimilitud intracluster: [np.float64(2.0002054831026763), np.float64(2.0000403252685306), np.float64(1.0000271308198043), np.float64(2.000046470949113), np.float64(2.0082754203527884), np.float64(2.000129202242305), np.float64(2.0000039700523096), np.float64(1.0019997557349452)]
# Cluster a dividir: 4
# Número de elementos a asignar al nuevo cluster 8: 1
# Paso número 9
# Disimilitud intracluster: [np.float64(2.0002054831026763), np.float64(2.0000403252685306), np.float64(1.0000271308198043), np.float64(2.000046470949113), np.float64(1.0023320485527738), np.float64(2.000129202242305), np.float64(2.0000039700523096), np.float64(1.0019997557349452), np.float64(0.0)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 9: 1
# Paso número 10
# Disimilitud intracluster: [np.float64(1.0000032665626648), np.float64(2.0000403252685306), np.float64(1.0000271308198043), np.float64(2.000046470949113), np.float64(1.0023320485527738), np.float64(2.000129202242305), np.float64(2.0000039700523096), np.float64(1.0019997557349452), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 5
# Número de elementos a asignar al nuevo cluster 10: 1
# Paso número 11
# Disimilitud intracluster: [np.float64(1.0000032665626648), np.float64(2.0000403252685306), np.float64(1.0000271308198043), np.float64(2.000046470949113), np.float64(1.0023320485527738), np.float64(1.000738313624496), np.float64(2.0000039700523096), np.float64(1.0019997557349452), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 3
# Número de elementos a asignar al nuevo cluster 11: 1
# Paso número 12
# Disimilitud intracluster: [np.float64(1.0000032665626648), np.float64(2.0000403252685306), np.float64(1.0000271308198043), np.float64(1.000321614530047), np.float64(1.0023320485527738), np.float64(1.000738313624496), np.float64(2.0000039700523096), np.float64(1.0019997557349452), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 12: 1
# Paso número 13
# Disimilitud intracluster: [np.float64(1.0000032665626648), np.float64(1.003878263781147), np.float64(1.0000271308198043), np.float64(1.000321614530047), np.float64(1.0023320485527738), np.float64(1.000738313624496), np.float64(2.0000039700523096), np.float64(1.0019997557349452), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 6
# Número de elementos a asignar al nuevo cluster 13: 1
# Paso número 14
# Disimilitud intracluster: [np.float64(1.0000032665626648), np.float64(1.003878263781147), np.float64(1.0000271308198043), np.float64(1.000321614530047), np.float64(1.0023320485527738), np.float64(1.000738313624496), np.float64(1.0008274346920403), np.float64(1.0019997557349452), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 14: 1
# Paso número 15
# Disimilitud intracluster: [np.float64(1.0000032665626648), np.float64(0.0), np.float64(1.0000271308198043), np.float64(1.000321614530047), np.float64(1.0023320485527738), np.float64(1.000738313624496), np.float64(1.0008274346920403), np.float64(1.0019997557349452), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 4
# Número de elementos a asignar al nuevo cluster 15: 1
# Paso número 16
# Disimilitud intracluster: [np.float64(1.0000032665626648), np.float64(0.0), np.float64(1.0000271308198043), np.float64(1.000321614530047), np.float64(0.0), np.float64(1.000738313624496), np.float64(1.0008274346920403), np.float64(1.0019997557349452), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 7
# Número de elementos a asignar al nuevo cluster 16: 1
# Paso número 17
# Disimilitud intracluster: [np.float64(1.0000032665626648), np.float64(0.0), np.float64(1.0000271308198043), np.float64(1.000321614530047), np.float64(0.0), np.float64(1.000738313624496), np.float64(1.0008274346920403), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 6
# Número de elementos a asignar al nuevo cluster 17: 1
# Paso número 18
# Disimilitud intracluster: [np.float64(1.0000032665626648), np.float64(0.0), np.float64(1.0000271308198043), np.float64(1.000321614530047), np.float64(0.0), np.float64(1.000738313624496), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 5
# Número de elementos a asignar al nuevo cluster 18: 1
# Paso número 19
# Disimilitud intracluster: [np.float64(1.0000032665626648), np.float64(0.0), np.float64(1.0000271308198043), np.float64(1.000321614530047), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 3
# Número de elementos a asignar al nuevo cluster 19: 1
# Paso número 20
# Disimilitud intracluster: [np.float64(1.0000032665626648), np.float64(0.0), np.float64(1.0000271308198043), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 2
# Número de elementos a asignar al nuevo cluster 20: 1
# Paso número 21
# Disimilitud intracluster: [np.float64(1.0000032665626648), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 21: 1

# %%
plot_dendrograma_de_mparticiones(mD, mParticiones)

# %%
plot_particion_K(Dx, mParticiones, K)
# Out:
# (<Figure size 1000x500 with 1 Axes>, <Axes: >)

# %%
# Usando disimilitud media y K-means como método de separacion
mParticiones = clustering_divisivo(mD, disimilitud_media, separacion_Kmeans, True, Dxglobal=Dx)
# Out:
# Paso número 1
# Disimilitud intracluster: [np.float64(7.320333481796019)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 1: 11
# Paso número 2
# Disimilitud intracluster: [np.float64(3.6401805352754173), np.float64(3.6388874885940994)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 2: 5
# Paso número 3
# Disimilitud intracluster: [np.float64(1.9469226515718252), np.float64(3.6388874885940994), np.float64(1.6004322959219144)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 3: 5
# Paso número 4
# Disimilitud intracluster: [np.float64(1.9469226515718252), np.float64(1.9447777636023769), np.float64(1.6004322959219144), np.float64(1.6003148325792946)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 4: 4
# Paso número 5
# Disimilitud intracluster: [np.float64(0.5011660242763869), np.float64(1.9447777636023769), np.float64(1.6004322959219144), np.float64(1.6003148325792946), np.float64(1.2514395756327443)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 5: 3
# Paso número 6
# Disimilitud intracluster: [np.float64(0.5011660242763869), np.float64(0.8894970042574598), np.float64(1.6004322959219144), np.float64(1.6003148325792946), np.float64(1.2514395756327443), np.float64(0.8890110365918285)]
# Cluster a dividir: 2
# Número de elementos a asignar al nuevo cluster 6: 2
# Paso número 7
# Disimilitud intracluster: [np.float64(0.5011660242763869), np.float64(0.8894970042574598), np.float64(0.8891396041288877), np.float64(1.6003148325792946), np.float64(1.2514395756327443), np.float64(0.8890110365918285), np.float64(0.5009998778674726)]
# Cluster a dividir: 3
# Número de elementos a asignar al nuevo cluster 7: 3
# Paso número 8
# Disimilitud intracluster: [np.float64(0.5011660242763869), np.float64(0.8894970042574598), np.float64(0.8891396041288877), np.float64(0.5000135654099022), np.float64(1.2514395756327443), np.float64(0.8890110365918285), np.float64(0.5009998778674726), np.float64(0.8892952818174589)]
# Cluster a dividir: 4
# Número de elementos a asignar al nuevo cluster 8: 2
# Paso número 9
# Disimilitud intracluster: [np.float64(0.5011660242763869), np.float64(0.8894970042574598), np.float64(0.8891396041288877), np.float64(0.5000135654099022), np.float64(0.5008643151738439), np.float64(0.8890110365918285), np.float64(0.5009998778674726), np.float64(0.8892952818174589), np.float64(0.5019391318905735)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 9: 2
# Paso número 10
# Disimilitud intracluster: [np.float64(0.5011660242763869), np.float64(0.0), np.float64(0.8891396041288877), np.float64(0.5000135654099022), np.float64(0.5008643151738439), np.float64(0.8890110365918285), np.float64(0.5009998778674726), np.float64(0.8892952818174589), np.float64(0.5019391318905735), np.float64(0.500369156812248)]
# Cluster a dividir: 7
# Número de elementos a asignar al nuevo cluster 10: 1
# Paso número 11
# Disimilitud intracluster: [np.float64(0.5011660242763869), np.float64(0.0), np.float64(0.8891396041288877), np.float64(0.5000135654099022), np.float64(0.5008643151738439), np.float64(0.8890110365918285), np.float64(0.5009998778674726), np.float64(0.5004137173460201), np.float64(0.5019391318905735), np.float64(0.500369156812248), np.float64(0.0)]
# Cluster a dividir: 2
# Número de elementos a asignar al nuevo cluster 11: 1
# Paso número 12
# Disimilitud intracluster: [np.float64(0.5011660242763869), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.5008643151738439), np.float64(0.8890110365918285), np.float64(0.5009998778674726), np.float64(0.5004137173460201), np.float64(0.5019391318905735), np.float64(0.500369156812248), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 5
# Número de elementos a asignar al nuevo cluster 12: 1
# Paso número 13
# Disimilitud intracluster: [np.float64(0.5011660242763869), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.5008643151738439), np.float64(0.5000016332813324), np.float64(0.5009998778674726), np.float64(0.5004137173460201), np.float64(0.5019391318905735), np.float64(0.500369156812248), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 8
# Número de elementos a asignar al nuevo cluster 13: 1
# Paso número 14
# Disimilitud intracluster: [np.float64(0.5011660242763869), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.5008643151738439), np.float64(0.5000016332813324), np.float64(0.5009998778674726), np.float64(0.5004137173460201), np.float64(0.0), np.float64(0.500369156812248), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 14: 1
# Paso número 15
# Disimilitud intracluster: [np.float64(0.0), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.5008643151738439), np.float64(0.5000016332813324), np.float64(0.5009998778674726), np.float64(0.5004137173460201), np.float64(0.0), np.float64(0.500369156812248), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 6
# Número de elementos a asignar al nuevo cluster 15: 1
# Paso número 16
# Disimilitud intracluster: [np.float64(0.0), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.5008643151738439), np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.5004137173460201), np.float64(0.0), np.float64(0.500369156812248), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 4
# Número de elementos a asignar al nuevo cluster 16: 1
# Paso número 17
# Disimilitud intracluster: [np.float64(0.0), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.0), np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.5004137173460201), np.float64(0.0), np.float64(0.500369156812248), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 7
# Número de elementos a asignar al nuevo cluster 17: 1
# Paso número 18
# Disimilitud intracluster: [np.float64(0.0), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.0), np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.500369156812248), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 9
# Número de elementos a asignar al nuevo cluster 18: 1
# Paso número 19
# Disimilitud intracluster: [np.float64(0.0), np.float64(0.0), np.float64(0.5001608072650235), np.float64(0.5000135654099022), np.float64(0.0), np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 2
# Número de elementos a asignar al nuevo cluster 19: 1
# Paso número 20
# Disimilitud intracluster: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.5000135654099022), np.float64(0.0), np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 3
# Número de elementos a asignar al nuevo cluster 20: 1
# Paso número 21
# Disimilitud intracluster: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.5000016332813324), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 5
# Número de elementos a asignar al nuevo cluster 21: 1

# %%
plot_dendrograma_de_mparticiones(mD, mParticiones)

# %%
plot_particion_K(Dx, mParticiones, K)
# Out:
# (<Figure size 1000x500 with 1 Axes>, <Axes: >)

# %%
# Usando disimilitud diámetro y K-means como método de separacion
mParticiones = clustering_divisivo(mD, disimilitud_diametro, separacion_Kmeans, True, Dxglobal=Dx)
# Out:
# Paso número 1
# Disimilitud intracluster: [np.float64(21.0000098308137)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 1: 11
# Paso número 2
# Disimilitud intracluster: [np.float64(10.00097531413936), np.float64(10.001327366161615)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 2: 5
# Paso número 3
# Disimilitud intracluster: [np.float64(10.00097531413936), np.float64(5.0025589292050325), np.float64(4.000157369331913)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 3: 5
# Paso número 4
# Disimilitud intracluster: [np.float64(5.001849350471439), np.float64(5.0025589292050325), np.float64(4.000157369331913), np.float64(4.00006378405076)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 4: 3
# Paso número 5
# Disimilitud intracluster: [np.float64(5.001849350471439), np.float64(2.006844253249925), np.float64(4.000157369331913), np.float64(4.00006378405076), np.float64(2.0006321208418103)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 5: 2
# Paso número 6
# Disimilitud intracluster: [np.float64(3.000354540080659), np.float64(2.006844253249925), np.float64(4.000157369331913), np.float64(4.00006378405076), np.float64(2.0006321208418103), np.float64(1.0023320485527738)]
# Cluster a dividir: 2
# Número de elementos a asignar al nuevo cluster 6: 2
# Paso número 7
# Disimilitud intracluster: [np.float64(3.000354540080659), np.float64(2.006844253249925), np.float64(2.0002054831026763), np.float64(4.00006378405076), np.float64(2.0006321208418103), np.float64(1.0023320485527738), np.float64(1.0018690032917676)]
# Cluster a dividir: 3
# Número de elementos a asignar al nuevo cluster 7: 3
# Paso número 8
# Disimilitud intracluster: [np.float64(3.000354540080659), np.float64(2.006844253249925), np.float64(2.0002054831026763), np.float64(1.0019997557349452), np.float64(2.0006321208418103), np.float64(1.0023320485527738), np.float64(1.0018690032917676), np.float64(2.000046470949113)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 8: 2
# Paso número 9
# Disimilitud intracluster: [np.float64(1.0017286303476878), np.float64(2.006844253249925), np.float64(2.0002054831026763), np.float64(1.0019997557349452), np.float64(2.0006321208418103), np.float64(1.0023320485527738), np.float64(1.0018690032917676), np.float64(2.000046470949113), np.float64(1.003878263781147)]
# Cluster a dividir: 1
# Número de elementos a asignar al nuevo cluster 9: 2
# Paso número 10
# Disimilitud intracluster: [np.float64(1.0017286303476878), np.float64(0.0), np.float64(2.0002054831026763), np.float64(1.0019997557349452), np.float64(2.0006321208418103), np.float64(1.0023320485527738), np.float64(1.0018690032917676), np.float64(2.000046470949113), np.float64(1.003878263781147), np.float64(1.0008274346920403)]
# Cluster a dividir: 4
# Número de elementos a asignar al nuevo cluster 10: 1
# Paso número 11
# Disimilitud intracluster: [np.float64(1.0017286303476878), np.float64(0.0), np.float64(2.0002054831026763), np.float64(1.0019997557349452), np.float64(1.0000271308198043), np.float64(1.0023320485527738), np.float64(1.0018690032917676), np.float64(2.000046470949113), np.float64(1.003878263781147), np.float64(1.0008274346920403), np.float64(0.0)]
# Cluster a dividir: 2
# Número de elementos a asignar al nuevo cluster 11: 2
# Paso número 12
# Disimilitud intracluster: [np.float64(1.0017286303476878), np.float64(0.0), np.float64(0.0), np.float64(1.0019997557349452), np.float64(1.0000271308198043), np.float64(1.0023320485527738), np.float64(1.0018690032917676), np.float64(2.000046470949113), np.float64(1.003878263781147), np.float64(1.0008274346920403), np.float64(0.0), np.float64(1.0000032665626648)]
# Cluster a dividir: 7
# Número de elementos a asignar al nuevo cluster 12: 1
# Paso número 13
# Disimilitud intracluster: [np.float64(1.0017286303476878), np.float64(0.0), np.float64(0.0), np.float64(1.0019997557349452), np.float64(1.0000271308198043), np.float64(1.0023320485527738), np.float64(1.0018690032917676), np.float64(1.000321614530047), np.float64(1.003878263781147), np.float64(1.0008274346920403), np.float64(0.0), np.float64(1.0000032665626648), np.float64(0.0)]
# Cluster a dividir: 8
# Número de elementos a asignar al nuevo cluster 13: 1
# Paso número 14
# Disimilitud intracluster: [np.float64(1.0017286303476878), np.float64(0.0), np.float64(0.0), np.float64(1.0019997557349452), np.float64(1.0000271308198043), np.float64(1.0023320485527738), np.float64(1.0018690032917676), np.float64(1.000321614530047), np.float64(0.0), np.float64(1.0008274346920403), np.float64(0.0), np.float64(1.0000032665626648), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 5
# Número de elementos a asignar al nuevo cluster 14: 1
# Paso número 15
# Disimilitud intracluster: [np.float64(1.0017286303476878), np.float64(0.0), np.float64(0.0), np.float64(1.0019997557349452), np.float64(1.0000271308198043), np.float64(0.0), np.float64(1.0018690032917676), np.float64(1.000321614530047), np.float64(0.0), np.float64(1.0008274346920403), np.float64(0.0), np.float64(1.0000032665626648), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 3
# Número de elementos a asignar al nuevo cluster 15: 1
# Paso número 16
# Disimilitud intracluster: [np.float64(1.0017286303476878), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(1.0000271308198043), np.float64(0.0), np.float64(1.0018690032917676), np.float64(1.000321614530047), np.float64(0.0), np.float64(1.0008274346920403), np.float64(0.0), np.float64(1.0000032665626648), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 6
# Número de elementos a asignar al nuevo cluster 16: 1
# Paso número 17
# Disimilitud intracluster: [np.float64(1.0017286303476878), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(1.0000271308198043), np.float64(0.0), np.float64(0.0), np.float64(1.000321614530047), np.float64(0.0), np.float64(1.0008274346920403), np.float64(0.0), np.float64(1.0000032665626648), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 0
# Número de elementos a asignar al nuevo cluster 17: 1
# Paso número 18
# Disimilitud intracluster: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(1.0000271308198043), np.float64(0.0), np.float64(0.0), np.float64(1.000321614530047), np.float64(0.0), np.float64(1.0008274346920403), np.float64(0.0), np.float64(1.0000032665626648), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 9
# Número de elementos a asignar al nuevo cluster 18: 1
# Paso número 19
# Disimilitud intracluster: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(1.0000271308198043), np.float64(0.0), np.float64(0.0), np.float64(1.000321614530047), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(1.0000032665626648), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 7
# Número de elementos a asignar al nuevo cluster 19: 1
# Paso número 20
# Disimilitud intracluster: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(1.0000271308198043), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(1.0000032665626648), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 4
# Número de elementos a asignar al nuevo cluster 20: 1
# Paso número 21
# Disimilitud intracluster: [np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(1.0000032665626648), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0)]
# Cluster a dividir: 11
# Número de elementos a asignar al nuevo cluster 21: 1

# %%
plot_dendrograma_de_mparticiones(mD, mParticiones)

# %%
plot_particion_K(Dx, mParticiones, K)
# Out:
# (<Figure size 1000x500 with 1 Axes>, <Axes: >)

# %% [markdown]
# <hr>
# <h2>Implementaciones en librerías de Python</h2>
#
# Dada la complejidad añadida del clustering jerárquico divisivo (respecto al aglomerativo), las principales librarías de aprendizaje automático de Python <b>no implementan</b> esta versión del agrupamiento jerárquico.

# %% [markdown]
# # 🎯 **EJ 2: Podemos hacer unas pruebas para ganar algunas intuiciones sobre cuál es la mejor estrategia según el tipo de datos...**

# %%
def plot_varios(Dx, Dy, K):
    cmap = plt.colormaps['tab20']
    n_samples = Dx.shape[0]
    vals = np.linspace(0, 1, n_samples + 2)[1:-1]  # Más eficiente
    rgba = cmap(vals)
    K = K-1
    fig, ax = plt.subplots(1, 5, figsize=(20, 5))

    # Gráfico 1: Datos originales
    ax[0].scatter(Dx[:, 0], Dx[:, 1], c=Dy)
    ax[0].set_title('Datos originales')

    # Gráfico 2: Disimilitud media y Macnaughton-Smith
    mD = matriz_distancias(Dx, distancia_euclidiana) # P1 Complete su codigo aqui
    mParticiones = clustering_divisivo(mD, disimilitud_media, separacion_macnaughton_smith, False)
    dy2 = mParticiones[:,K]
    ax[1].scatter(Dx[:, 0], Dx[:, 1], c=dy2)
    ax[1].set_title('Disimilitud media y Macnaughton-Smith')

    # Gráfico 3: Disimilitud media y Kmeans
    mParticiones = clustering_divisivo(mD, disimilitud_media, separacion_Kmeans, False, Dxglobal=Dx) # Extraer partición con exactamente k clústeres
    dy2 = mParticiones[:,K] # Extraer partición con exactamente k clústeres
    ax[2].scatter(Dx[:, 0], Dx[:, 1], c=dy2)
    ax[2].set_title('Disimilitud media y Kmeans')

    # Gráfico 4: Disimilitud diametro y Macnaughton-Smith
    mParticiones = clustering_divisivo(mD, disimilitud_diametro, separacion_macnaughton_smith, False) # P10. Tu código aquí ##
    dy2 = mParticiones[:,K] # P10. Tu código aquí ##
    ax[3].scatter(Dx[:, 0], Dx[:, 1], c=dy2)
    ax[3].set_title('Disimilitud diametro y Macnaughton-Smith')

    # Gráfico 5: Disimilitud diametro y Kmeans
    mParticiones = clustering_divisivo(mD, disimilitud_diametro, separacion_Kmeans, False, Dxglobal=Dx) # P11. Tu código aquí ##
    dy2 = mParticiones[:,K] # P11. Tu código aquí ##
    ax[4].scatter(Dx[:, 0], Dx[:, 1], c=dy2)
    ax[4].set_title('Disimilitud diametro y Kmeans')

    plt.tight_layout()
    plt.show()

# %%
D# Cargar dataset
D =cargar_dataset_csv("dataset_dos_remolinos.csv")
D = D[ np.random.choice(np.arange(D.shape[0]), D.shape[0], replace=False) ,:]
Dx = D[:,0:2]
Dy = D[:,2]
plot_varios(Dx,Dy,2)
# Out:
# ✅ Dataset cargado desde URL GitHub

# %%
def generar_dataset_2d_con_etiquetas(n_muestras=30, seed=42):
    np.random.seed(seed)

    # Crear 3 grupos naturales
    n1 = n_muestras // 3
    n2 = n_muestras // 3
    n3 = n_muestras - n1 - n2

    # Grupo 1: Centro en (2, 2) - Etiqueta 0
    grupo1 = np.random.randn(n1, 2) * 0.5 + np.array([2, 2])
    etiquetas1 = np.zeros(n1, dtype=int)

    # Grupo 2: Centro en (8, 3) - Etiqueta 1
    grupo2 = np.random.randn(n2, 2) * 0.6 + np.array([8, 3])
    etiquetas2 = np.ones(n2, dtype=int)

    # Grupo 3: Centro en (5, 8) - Etiqueta 2
    grupo3 = np.random.randn(n3, 2) * 0.4 + np.array([5, 8])
    etiquetas3 = np.full(n3, 2, dtype=int)

    # Puntos ruidosos/intermedios - Etiqueta 3 (ruido)
    n_ruido = max(2, n_muestras // 10)
    ruido = np.random.rand(n_ruido, 2) * 10
    etiquetas_ruido = np.full(n_ruido, 3, dtype=int)

    # Combinar todos los puntos y etiquetas
    datos = np.vstack([grupo1, grupo2, grupo3, ruido])
    etiquetas = np.concatenate([etiquetas1, etiquetas2, etiquetas3, etiquetas_ruido])

    # Mezclar los puntos y etiquetas manteniendo la correspondencia
    indices_mezclados = np.random.permutation(len(datos))
    datos = datos[indices_mezclados]
    etiquetas = etiquetas[indices_mezclados]

    return datos, etiquetas

# %%
Dx, Dy = generar_dataset_2d_con_etiquetas(n_muestras=30, seed=42)

# %%
plot_varios(Dx,Dy,5)

# %% [markdown]
# # 🚀 ¡TALLER FINALIZADO!"
